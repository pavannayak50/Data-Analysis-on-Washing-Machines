# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
df1=pd.read_csv(r"C:\Users\DELL\DATA SCIENCE\MY OWN GROUP\DATA CLEANED.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/983163021.py in <module>
# ----> 1 df1=pd.read_csv(r"C:\Users\DELL\DATA SCIENCE\MY OWN GROUP\DATA CLEANED.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/1970589316.py in <module>
# ----> 1 df1.head()
#
# NameError: name 'df1' is not defined

# %%
df=df1.drop(['Unnamed: 0'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/67252374.py in <module>
# ----> 1 df=df1.drop(['Unnamed: 0'], axis = 1)
#
# NameError: name 'df1' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df["Brands"].value_counts()

# %%
df["Brands"],df["Prices"].max()

# %%
df[df['Capacity']==7]

# %%
df.groupby(by="Brands")["Prices","Capacity","RPM"].max().head()

# %%
df.groupby(by="Brands")["Prices","Capacity"].min().head()

# %%
df.groupby(by="Brands")["Prices","Capacity","Rating"].max()

# %%
df.groupby(by="Prices").min().head(10)

# %%
df.groupby(by="Prices").max()

# %%
df.groupby(['Brands','LOADS']).count()

# %%
sns.boxplot(df['Capacity'],df['Prices'])

# %%
plt.figure(figsize=(20,12))

sns.scatterplot(df['Capacity'],df['Prices'],hue=df['Brands'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##  Corelation plot

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.distplot(df['Capacity'])

# %% [markdown]
# ###  its is in positively skewed

# %%
sns.distplot(df['Prices'])

# %% [markdown]
# #### in distplot prices   are in between 7000  to 45000

# %%
sns.boxplot(data =df, x='Brands', y='Prices')
plt.xticks(rotation=90)
plt.figure(figsize=(30,40))

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Brands', y='Prices', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='Brands', y='Capacity', data=df)

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='Brands', y='Prices', data=df)

plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/3850468726.py in <module>
#       1 plt.figure(figsize=(15,10))
# ----> 2 sns.boxplot(x='Brands', y='Prices', data=df)
#       3
#       4 plt.xticks(rotation=90)
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Brands', y='Prices', data=df,ci=None)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/2904759475.py in <module>
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.barplot(x='Brands', y='Prices', data=df,ci=None)
#       3 plt.xticks(rotation=90)
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Capacity', data=df)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/4080723079.py in <module>
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.countplot(x='Capacity', data=df)
#       3 plt.xticks(rotation=90)
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.catplot(x='Brands', data=df, kind='count')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='Brands', y='Capacity', data=df, kind='box')  
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Capacity', y='Prices', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Brands', y='Prices', data=df,ci=None)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='RPM', y='Prices', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.scatter(x='Brands', y='Prices', data=df)  
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### under 20000  we have  Singer,voltas intex  washing machines

# %%
plt.hist(df["Brands"],edgecolor="black")
plt.legend()
plt.xticks(rotation=90)
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df["Prices"],edgecolor="pink",label="Prices")
plt.legend()
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['Brands', 'Prices', 'Capacity', 'RPM', 'LOADS', 'Rating', 'Warranty'], dtype='object')

# %%
plt.hist(df["Capacity"],edgecolor = 'black')
# Out:
# (array([ 1., 83.,  2., 98., 89., 39., 69., 38., 19.,  4.]),
#  array([5.2 , 5.63, 6.06, 6.49, 6.92, 7.35, 7.78, 8.21, 8.64, 9.07, 9.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["RPM"],edgecolor = 'black' )
plt.xticks(rotation=90)
plt.show
plt.figure(figsize=(30,10))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brands    442 non-null    object
#  1   Prices    442 non-null    int64
#  2   Capacity  442 non-null    float64
#  3   RPM       442 non-null    object
#  4   LOADS     442 non-null    object
#  5   Rating    442 non-null    int64
#  6   Warranty  442 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 24.3+ KB

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='Prices')

# %%
df
# Out:
#         Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 0           LG   11990       7.0  1350   Semi       5         2
# 1      SAMSUNG   15090       6.5   680  Fully       3         2
# 2    Whirlpool   10740       7.0   746   Semi       5         2
# 3      SAMSUNG    9990       6.5  1400   Semi       5         2
# 4      SAMSUNG   10690       7.0  1350   Semi       5         2
# ..         ...     ...       ...   ...    ...     ...       ...
# 437      Croma   19990       6.5    12  Fully       5         2
# 438         LG   15299       7.0  1400   Semi       5         2
# 439    SAMSUNG   23490       7.0    14   Semi       5         2
# 440     Godrej   30290       8.0    10  Fully       5         2
# 441      Haier   15290       6.0  1300   Semi       5         2
#
# [442 rows x 7 columns]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Brands', y='Prices', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# brand=['Full load','Semi load']
# plt.pie(labels,labels=brand,autopct='%.2f%%')
# plt.figure(figsize=(120,80),dpi=100)
# plt.show()
# plt.legend;

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Brands', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.distplot(df['Prices'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Prices', ylabel='Density'>

# %%
sns.histplot(df['Capacity'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(df)

# %%
df[df['Prices']==25000]
# Out:
#       Brands  Prices  Capacity  RPM LOADS  Rating  Warranty
# 344  SAMSUNG   25000       7.0  740  Semi       5         3

# %%
df[df['LOADS']=="Fully"]
# Out:
#         Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 1      SAMSUNG   15090       6.5   680  Fully       3         2
# 6       realme   17190       8.0   700  Fully       5         2
# 9    Whirlpool   17090       7.0  1400  Fully       5         2
# 10     SAMSUNG   17390       6.5   740  Fully       5         3
# 12     SAMSUNG   19190       7.0   700  Fully       5         3
# ..         ...     ...       ...   ...    ...     ...       ...
# 430   MOTOROLA   24990       8.5    10  Fully       5         2
# 434  Whirlpool   15990       6.5  1200  Fully       5         2
# 436    SAMSUNG   34299       7.0    10  Fully       5         3
# 437      Croma   19990       6.5    12  Fully       5         2
# 440     Godrej   30290       8.0    10  Fully       5         2
#
# [203 rows x 7 columns]

# %%
df2=df.loc[(df["LOADS"]=="Fully")&(df["Prices"]<25000)&(df["Prices"]>20000)]

# %%
df2.head()
# Out:
#      Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 15  SAMSUNG   24990       6.0   750  Fully       5         3
# 27  SAMSUNG   23490       6.0   800  Fully       5         3
# 51  SAMSUNG   23490       6.0    10  Fully       5         1
# 63  SAMSUNG   24990       6.0   750  Fully       5         3
# 80       LG   20490       7.0  1400  Fully       5         2

# %%
df2=df.loc[(df["Brands"]=="IFB")&(df["Prices"]>=20000)&(df["Capacity"]==8.5)&(df["LOADS"]=="Fully")]

# %%
df2
# Out:
#     Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 238    IFB   29390       8.5  1000  Fully       5         4
# 276    IFB   20390       8.5  1350  Fully       5         3

# %%
df2=df.loc[(df["Brands"]=="SAMSUNG")&(df["Prices"]<=20000)&(df["Capacity"]<=7)&(df["LOADS"]=="Fully")&(df["Warranty"]==2)&(df["Rating"])]

# %%
df2
# Out:
#       Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 1    SAMSUNG   15090       6.5   680  Fully       3         2
# 55   SAMSUNG    9990       6.5    10  Fully       5         2
# 65   SAMSUNG   17490       7.0    10  Fully       5         2
# 79   SAMSUNG    9990       7.0    10  Fully       5         2
# 83   SAMSUNG    9490       6.0    10  Fully       5         2
# 107  SAMSUNG    9990       7.0    10  Fully       3         2
# 131  SAMSUNG    9990       6.5  1400  Fully       5         2
# 146  SAMSUNG   16100       7.0  1400  Fully       5         2
# 240  SAMSUNG   14200       6.5   700  Fully       5         2
# 250  SAMSUNG   17840       6.0    10  Fully       5         2
# 251  SAMSUNG    9990       7.0  1450  Fully       5         2
# 295  SAMSUNG    9990       6.0  1000  Fully       5         2
# 327  SAMSUNG    9490       6.5    10  Fully       5         2
# 351  SAMSUNG    9490       6.5   750  Fully       5         2
# ...

# %%
df2=df.loc[(df["Brands"]=="SAMSUNG")&(df["Prices"]<=20000)&(df["Capacity"]<=7)&(df["LOADS"]=="Fully")&(df["Warranty"]==2)&(df["Rating"])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/2890203407.py in <module>
# ----> 1 df2=df.loc[(df["Brands"]=="SAMSUNG")&(df["Prices"]<=20000)&(df["Capacity"]<=7)&(df["LOADS"]=="Fully")&(df["Warranty"]==2)&(df["Rating"])]
#
# NameError: name 'df' is not defined
