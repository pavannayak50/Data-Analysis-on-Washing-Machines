# %% [markdown]
# ### ANALYSIS  on Washing Machine from Flipkart

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\DELL\DATA SCIENCE\MY OWN GROUP\NEW WASHING.csv")

# %%
df
# Out:
#      Unnamed: 0     Brands   Prices  Capacity   RPM  LOADS  Rating  Warranty
# 0             0    SAMSUNG  ₹14,490       6.5   680  Fully       3         2
# 1             1    SAMSUNG  ₹18,490       7.0   750  Fully       5         3
# 2             2  Whirlpool   ₹9,990       7.0    12   Semi       5         2
# 3             3    SAMSUNG  ₹36,990       8.0  1450   Semi       5         3
# 4             4         LG  ₹11,190       7.0  1400  Fully       5         2
# ..          ...        ...      ...       ...   ...    ...     ...       ...
# 437         437         LG  ₹40,968       6.5    10   Semi       5         3
# 438         438  Whirlpool  ₹13,990       9.5   700   Semi       5         2
# 439         439    SAMSUNG  ₹31,990       7.0    10   Semi       5         2
# 440         440         LG  ₹36,199       6.0  1500   Semi       5         2
# 441         441      BOSCH  ₹41,900       7.0  1000   Semi       5         2
#
# [442 rows x 8 columns]

# %% [markdown]
#  ### The Pandas drop () function in Python is used to drop specified labels from rows and columns. Drop is a major function used to clean the dataset.

# %%
df1 = df.drop('Unnamed: 0',axis=1)
df1
# Out:
#         Brands   Prices  Capacity   RPM  LOADS  Rating  Warranty
# 0      SAMSUNG  ₹14,490       6.5   680  Fully       3         2
# 1      SAMSUNG  ₹18,490       7.0   750  Fully       5         3
# 2    Whirlpool   ₹9,990       7.0    12   Semi       5         2
# 3      SAMSUNG  ₹36,990       8.0  1450   Semi       5         3
# 4           LG  ₹11,190       7.0  1400  Fully       5         2
# ..         ...      ...       ...   ...    ...     ...       ...
# 437         LG  ₹40,968       6.5    10   Semi       5         3
# 438  Whirlpool  ₹13,990       9.5   700   Semi       5         2
# 439    SAMSUNG  ₹31,990       7.0    10   Semi       5         2
# 440         LG  ₹36,199       6.0  1500   Semi       5         2
# 441      BOSCH  ₹41,900       7.0  1000   Semi       5         2
#
# [442 rows x 7 columns]

# %% [markdown]
# ### shape()  is  used  to  get   no of   rows and  columns  in data

# %%
df.shape
# Out:
# (442, 8)

# %% [markdown]
# ### The info () function is used to print a concise summary of a DataFrame
#
# #### . concise   means  lot of information

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brands    442 non-null    object
#  1   Prices    442 non-null    object
#  2   Capacity  442 non-null    float64
#  3   RPM       442 non-null    int64
#  4   LOADS     442 non-null    object
#  5   Rating    442 non-null    int64
#  6   Warranty  442 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 24.3+ KB

# %%
len(df1)
# Out:
# 442

# %% [markdown]
# ###   here  created  empty list to  remove ₹ symbol  in prices  i have used  repace()

# %%
a = []
for i in df1['Prices']:
    a.append(i.replace("₹","").replace(",",""))
    
df1['Prices']  = a

# %%
df1
# Out:
#         Brands Prices  Capacity   RPM  LOADS  Rating  Warranty
# 0      SAMSUNG  14490       6.5   680  Fully       3         2
# 1      SAMSUNG  18490       7.0   750  Fully       5         3
# 2    Whirlpool   9990       7.0    12   Semi       5         2
# 3      SAMSUNG  36990       8.0  1450   Semi       5         3
# 4           LG  11190       7.0  1400  Fully       5         2
# ..         ...    ...       ...   ...    ...     ...       ...
# 437         LG  40968       6.5    10   Semi       5         3
# 438  Whirlpool  13990       9.5   700   Semi       5         2
# 439    SAMSUNG  31990       7.0    10   Semi       5         2
# 440         LG  36199       6.0  1500   Semi       5         2
# 441      BOSCH  41900       7.0  1000   Semi       5         2
#
# [442 rows x 7 columns]

# %%
df1["Prices"]=pd.to_numeric(df1["Prices"])

# %%
df1["Prices"]
# Out:
# 0      14490
# 1      18490
# 2       9990
# 3      36990
# 4      11190
#        ...
# 437    40968
# 438    13990
# 439    31990
# 440    36199
# 441    41900
# Name: Prices, Length: 442, dtype: int64

# %%
df1.head(10)
# Out:
#       Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 0    SAMSUNG   14490       6.5   680  Fully       3         2
# 1    SAMSUNG   18490       7.0   750  Fully       5         3
# 2  Whirlpool    9990       7.0    12   Semi       5         2
# 3    SAMSUNG   36990       8.0  1450   Semi       5         3
# 4         LG   11190       7.0  1400  Fully       5         2
# 5         LG   17990       7.0    10   Semi       5         2
# 6         LG   14990       8.5  1350   Semi       5         2
# 7    SAMSUNG   31990       8.0   700  Fully       5         3
# 8       MarQ    6990       6.0    10   Semi       5         2
# 9     realme   14990       8.0  1300  Fully       5         2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brands    442 non-null    object
#  1   Prices    442 non-null    int64
#  2   Capacity  442 non-null    float64
#  3   RPM       442 non-null    int64
#  4   LOADS     442 non-null    object
#  5   Rating    442 non-null    int64
#  6   Warranty  442 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 24.3+ KB

# %% [markdown]
# ### describe () in Python The describe () method is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame

# %%
df1.describe()
# Out:
#               Prices    Capacity          RPM      Rating    Warranty
# count     442.000000  442.000000   442.000000  442.000000  442.000000
# mean    21573.457014    7.321719   648.871041    4.979638    2.343891
# std     11936.502529    0.886957   602.441182    0.195277    0.638395
# min      4990.000000    3.000000    10.000000    3.000000    1.000000
# 25%     12690.000000    6.500000    10.000000    5.000000    2.000000
# 50%     17990.000000    7.200000   700.000000    5.000000    2.000000
# 75%     29990.000000    8.000000  1300.000000    5.000000    3.000000
# max    109090.000000    9.500000  2000.000000    5.000000    4.000000

# %% [markdown]
# ###  isnull  is  used  to get  all  the null  values

# %%
df1.isnull().sum()
# Out:
# Brands      0
# Prices      0
# Capacity    0
# RPM         0
# LOADS       0
# Rating      0
# Warranty    0
# dtype: int64

# %%
df1.describe()
# Out:
#               Prices    Capacity          RPM      Rating    Warranty
# count     442.000000  442.000000   442.000000  442.000000  442.000000
# mean    21573.457014    7.321719   648.871041    4.979638    2.343891
# std     11936.502529    0.886957   602.441182    0.195277    0.638395
# min      4990.000000    3.000000    10.000000    3.000000    1.000000
# 25%     12690.000000    6.500000    10.000000    5.000000    2.000000
# 50%     17990.000000    7.200000   700.000000    5.000000    2.000000
# 75%     29990.000000    8.000000  1300.000000    5.000000    3.000000
# max    109090.000000    9.500000  2000.000000    5.000000    4.000000

# %%
df1["LOADS"]
# Out:
# 0      Fully
# 1      Fully
# 2       Semi
# 3       Semi
# 4      Fully
#        ...
# 437     Semi
# 438     Semi
# 439     Semi
# 440     Semi
# 441     Semi
# Name: LOADS, Length: 442, dtype: object

# %% [markdown]
# ###   to get  total brands  in   dat frame   we use   unique

# %%
df1['Brands'].unique()
# Out:
# array(['SAMSUNG', 'Whirlpool', 'LG', 'MarQ', 'realme', 'IFB', 'Haier',
#        'Thomson', 'Candes', 'ONIDA', 'BOSCH', 'Godrej', 'Croma',
#        'MOTOROLA', 'Sansui', 'Panasonic', 'Midea', 'Motorola', 'White',
#        'Singer', 'Lifelong', 'TCL', 'Lloyd', 'Galanz', 'DMR', 'Voltas',
#        'TOSHIBA', 'CANDY', 'Samsung', 'Hafele', 'RGL'], dtype=object)

# %%
df1['Brands'].value_counts()
# Out:
# SAMSUNG      88
# Whirlpool    74
# LG           62
# IFB          38
# Candes       29
# MarQ         20
# BOSCH        19
# Godrej       13
# Haier        10
# ONIDA        10
# MOTOROLA      9
# White         7
# Panasonic     7
# Croma         7
# realme        6
# Galanz        6
# Lloyd         6
# Thomson       6
# Sansui        4
# Motorola      3
# TCL           3
# DMR           3
# Voltas        3
# Midea         2
# Singer        1
# Lifelong      1
# TOSHIBA       1
# CANDY         1
# Samsung       1
# Hafele        1
# RGL           1
# Name: Brands, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brands    442 non-null    object
#  1   Prices    442 non-null    int64
#  2   Capacity  442 non-null    float64
#  3   RPM       442 non-null    int64
#  4   LOADS     442 non-null    object
#  5   Rating    442 non-null    int64
#  6   Warranty  442 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 24.3+ KB

# %%
df1['Prices'] = df1['Prices'].astype('int')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brands    442 non-null    object
#  1   Prices    442 non-null    int32
#  2   Capacity  442 non-null    float64
#  3   RPM       442 non-null    int64
#  4   LOADS     442 non-null    object
#  5   Rating    442 non-null    int64
#  6   Warranty  442 non-null    int64
# dtypes: float64(1), int32(1), int64(3), object(2)
# memory usage: 22.6+ KB

# %%
df1
# Out:
#         Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 0      SAMSUNG   14490       6.5   680  Fully       3         2
# 1      SAMSUNG   18490       7.0   750  Fully       5         3
# 2    Whirlpool    9990       7.0    12   Semi       5         2
# 3      SAMSUNG   36990       8.0  1450   Semi       5         3
# 4           LG   11190       7.0  1400  Fully       5         2
# ..         ...     ...       ...   ...    ...     ...       ...
# 437         LG   40968       6.5    10   Semi       5         3
# 438  Whirlpool   13990       9.5   700   Semi       5         2
# 439    SAMSUNG   31990       7.0    10   Semi       5         2
# 440         LG   36199       6.0  1500   Semi       5         2
# 441      BOSCH   41900       7.0  1000   Semi       5         2
#
# [442 rows x 7 columns]

# %%
df7=df1.groupby(['Brands', 'Prices'])
df5= pd.DataFrame(df7)
df5
# Out:
#                    0                                                  1
# 0      (BOSCH, 9699)      Brands  Prices  Capacity  RPM  LOADS  Rati...
# 1     (BOSCH, 10290)     Brands  Prices  Capacity  RPM LOADS  Rating...
# 2     (BOSCH, 12990)      Brands  Prices  Capacity  RPM  LOADS  Rati...
# 3     (BOSCH, 14490)      Brands  Prices  Capacity   RPM LOADS  Rati...
# 4     (BOSCH, 17690)      Brands  Prices  Capacity  RPM LOADS  Ratin...
# ..               ...                                                ...
# 365  (realme, 13990)      Brands  Prices  Capacity  RPM LOADS  Ratin...
# 366  (realme, 14990)     Brands  Prices  Capacity   RPM  LOADS  Rati...
# 367  (realme, 17690)      Brands  Prices  Capacity  RPM  LOADS  Rati...
# 368  (realme, 30490)      Brands  Prices  Capacity  RPM  LOADS  Rati...
# 369  (realme, 34990)       Brands  Prices  Capacity  RPM  LOADS  Rat...
#
# [370 rows x 2 columns]

# %%
df1.groupby(['Brands']).max()
# Out:
#            Prices  Capacity   RPM  LOADS  Rating  Warranty
# Brands
# BOSCH       43990       9.0  1500   Semi       5         4
# CANDY       36690       6.0    10   Semi       5         2
# Candes      56489       9.0  1500   Semi       5         4
# Croma       40199       9.5  1440   Semi       5         4
# DMR         13490       8.0  1200   Semi       5         4
# Galanz      45490       8.0  1400   Semi       5         3
# Godrej     109090       8.0  1400   Semi       5         4
# Hafele      17690       6.0    10  Fully       5         2
# Haier       30890       8.5  1400   Semi       5         4
# IFB         40199       9.0  1500   Semi       5         4
# LG          69990       9.0  1500   Semi       5         4
# Lifelong    31990       6.0  1300  Fully       5         2
# Lloyd       40990       8.5   800   Semi       5         4
# MOTOROLA    40207       9.0  1400   Semi       5         4
# MarQ        74990       8.5  1400   Semi       5         4
# ...

# %%
grp = df1.groupby(['Brands', 'Capacity'])
for name, group in grp:
    print(name)
    print(group)
    print()
# Out:
# ('BOSCH', 6.0)
#     Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 28   BOSCH   24490       6.0   740   Semi       5         2
# 60   BOSCH   37990       6.0  1000  Fully       5         2
# 262  BOSCH   19590       6.0  1500   Semi       5         2
#
# ('BOSCH', 6.5)
#     Brands  Prices  Capacity  RPM  LOADS  Rating  Warranty
# 140  BOSCH   39990       6.5  740   Semi       5         2
# 332  BOSCH   24990       6.5   10  Fully       5         2
# 369  BOSCH   29400       6.5   10  Fully       5         2
#
# ('BOSCH', 7.0)
#     Brands  Prices  Capacity   RPM  LOADS  Rating  Warranty
# 38   BOSCH   28990       7.0    10   Semi       5         2
# 49   BOSCH   10290       7.0   800   Semi       5         3
# 89   BOSCH   32990       7.0  1450  Fully       5         2
# 405  BOSCH   21990       7.0    14   Semi       5         2
# 441  BOSCH   41900       7.0  1000   Semi       5         2
#
# ('BOSCH', 7.2)
#     Brands  Prices  Capacity   RPM LOADS  Rating  Warranty
# ...

# %%
df1[['Brands','Prices','Capacity','RPM']].min()
# Out:
# Brands      BOSCH
# Prices       4990
# Capacity      3.0
# RPM            10
# dtype: object

# %%
df1[['Brands','Prices','Capacity','RPM']].max()
# Out:
# Brands      realme
# Prices      109090
# Capacity       9.5
# RPM           2000
# dtype: object

# %%
df2=df1.to_csv("DATA CLEANED .csv")

# %% [markdown]
# ## Advantages of semi automatic washing machine
#
# #### Does not continous water supply. This will much helpful if you are living in water crisis area.
# #### Small duration wash cycle.
# #### Consumes less water compared to fully automatic washing machine.
# #### Lightweight, easily movable
